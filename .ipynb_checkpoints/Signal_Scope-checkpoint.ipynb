# %%
import PyQt5

# %%
# %matplotlib qt5

# %%
# !pip install mpl_finance
# Out:
# Requirement already satisfied: mpl_finance in c:\users\luv\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: matplotlib in c:\users\luv\anaconda3\lib\site-packages (from mpl_finance) (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\luv\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mpl_finance) (1.16.0)

# %%
# !pip install --upgrade mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\luv\anaconda3\lib\site-packages (0.12.9b7)
# Requirement already satisfied: matplotlib in c:\users\luv\anaconda3\lib\site-packages (from mplfinance) (3.5.2)
# Requirement already satisfied: pandas in c:\users\luv\anaconda3\lib\site-packages (from mplfinance) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mplfinance) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\luv\anaconda3\lib\site-packages (from matplotlib->mplfinance) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\luv\anaconda3\lib\site-packages (from pandas->mplfinance) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\luv\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)

# %%
from IPython.display import Image
from matplotlib.lines import Line2D
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import mpl_finance as mpf
import matplotlib.dates as mdates

# %%
# !pip show ta-lib
# Out:
# Name: TA-Lib
# Version: 0.4.19
# Summary: Python wrapper for TA-Lib
# Home-page: http://github.com/mrjbq7/ta-lib
# Author: John Benediktsson
# Author-email: mrjbq7@gmail.com
# License: BSD
# Location: c:\users\luv\anaconda3\lib\site-packages
# Requires: numpy
# Required-by:

# %%
import talib

# %%
tickerSymbol = 'AAPL'

tickerData = yf.Ticker(tickerSymbol)

df = tickerData.history(period='1d', start='2022-3-8', end='2023-3-8')

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-03-08 00:00:00-05:00  157.863715  161.899267  154.861895  156.492020
# 2022-03-09 00:00:00-05:00  160.507692  162.426078  158.450163  161.968842
# 2022-03-10 00:00:00-05:00  159.235398  159.424257  155.040807  157.565521
# 2022-03-11 00:00:00-05:00  157.973048  158.320947  153.569729  153.798340
# 2022-03-14 00:00:00-04:00  150.538078  153.191999  149.196216  149.713074
# ...                               ...         ...         ...         ...
# 2023-03-01 00:00:00-05:00  146.830002  147.229996  145.009995  145.309998
# 2023-03-02 00:00:00-05:00  144.380005  146.710007  143.899994  145.910004
# 2023-03-03 00:00:00-05:00  148.039993  151.110001  147.330002  151.029999
# 2023-03-06 00:00:00-05:00  153.789993  156.300003  153.460007  153.830002
# 2023-03-07 00:00:00-05:00  153.699997  154.029999  151.130005  151.600006
#
#                               Volume  Dividends  Stock Splits
# Date
# 2022-03-08 00:00:00-05:00  131148300        0.0           0.0
# 2022-03-09 00:00:00-05:00   91454900        0.0           0.0
# 2022-03-10 00:00:00-05:00  105342000        0.0           0.0
# 2022-03-11 00:00:00-05:00   96970100        0.0           0.0
# 2022-03-14 00:00:00-04:00  108732100        0.0           0.0
# ...                              ...        ...           ...
# 2023-03-01 00:00:00-05:00   55479000        0.0           0.0
# 2023-03-02 00:00:00-05:00   52238100        0.0           0.0
# 2023-03-03 00:00:00-05:00   70668500        0.0           0.0
# 2023-03-06 00:00:00-05:00   87558000        0.0           0.0
# 2023-03-07 00:00:00-05:00   56182000        0.0           0.0
#
# [251 rows x 7 columns]

# %%
df['SMA20'] = talib.SMA(df['Close'], timeperiod=20)
df['SMA50'] = talib.SMA(df['Close'], timeperiod=50)
df['RSI'] = talib.RSI(df['Close'].values, timeperiod=14)

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'SMA20', 'SMA50', 'RSI'],
#       dtype='object')

# %%
# df['Date']=pd.to_datetime(df.index)

# %%
# df['Date']

# %%
# df.index= mdates.date2num(df.index)

# %%
plt.rcParams['figure.figsize'] = [12, 12]
plt.rc('font', size=14)

# %%
df['Date']=mdates.date2num(df.index)

# %%
fig, ax = plt.subplots()

# %%
mpf.candlestick_ohlc(ax, df[['Date','Open', 'High', 'Low', 'Close']].values, width=0.8, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1cfcdebb490>,
#   <matplotlib.lines.Line2D at 0x1cfcc85c670>,
#   <matplotlib.lines.Line2D at 0x1cfccba5c10>,
#   <matplotlib.lines.Line2D at 0x1cfcd209a90>,
#   <matplotlib.lines.Line2D at 0x1cfcf2a7310>,
#   <matplotlib.lines.Line2D at 0x1cfcf2a7af0>,
#   <matplotlib.lines.Line2D at 0x1cfcf2a7c10>,
#   <matplotlib.lines.Line2D at 0x1cfd31e6760>,
#   <matplotlib.lines.Line2D at 0x1cfd31e6f70>,
#   <matplotlib.lines.Line2D at 0x1cfd3f2bf10>,
#   <matplotlib.lines.Line2D at 0x1cfd3f2b9d0>,
#   <matplotlib.lines.Line2D at 0x1cfd3f2bf70>,
#   <matplotlib.lines.Line2D at 0x1cfccd63970>,
#   <matplotlib.lines.Line2D at 0x1cfccd63b20>,
#   <matplotlib.lines.Line2D at 0x1cfc1041100>,
#   <matplotlib.lines.Line2D at 0x1cfcb2a9d60>,
#   <matplotlib.lines.Line2D at 0x1cfd9fc28b0>,
#   <matplotlib.lines.Line2D at 0x1cfd9fc2d90>,
#   <matplotlib.lines.Line2D at 0x1cfcd2902b0>,
#   <matplotlib.lines.Line2D at 0x1cfcd290790>,
#   <matplotlib.lines.Line2D at 0x1cfcd290c70>,
#   <matplotlib.lines.Line2D at 0x1cfcd299190>,
#   <matplotlib.lines.Line2D at 0x1cfcd299670>,
#   <matplotlib.lines.Line2D at 0x1cfcd299b50>,
#   <matplotlib.lines.Line2D at 0x1cfcd299fd0>,
#   <matplotlib.lines.Line2D at 0x1cfcc543550>,
#   <matplotlib.lines.Line2D at 0x1cfcc543a30>,
#   <matplotlib.lines.Line2D at 0x1cfcc543f10>,
#   <matplotlib.lines.Line2D at 0x1cfcc559430>,
#   <matplotlib.lines.Line2D at 0x1cfcc559910>,
#   <matplotlib.lines.Line2D at 0x1cfcc559df0>,
#   <matplotlib.lines.Line2D at 0x1cfcc54c310>,
#   <matplotlib.lines.Line2D at 0x1cfcc54c7f0>,
#   <matplotlib.lines.Line2D at 0x1cfcc54ccd0>,
#   <matplotlib.lines.Line2D at 0x1cfcf2cc1f0>,
#   <matplotlib.lines.Line2D at 0x1cfcf2cc6d0>,
#   <matplotlib.lines.Line2D at 0x1cfcf2ccbb0>,
#   <matplotlib.lines.Line2D at 0x1cfcf2ccfd0>,
#   <matplotlib.lines.Line2D at 0x1cfcf2a65b0>,
#   <matplotlib.lines.Line2D at 0x1cfcf2a6a90>,
#   <matplotlib.lines.Line2D at 0x1cfcf2a6f70>,
#   <matplotlib.lines.Line2D at 0x1cfcf2d0490>,
#   <matplotlib.lines.Line2D at 0x1cfcf2d0970>,
#   <matplotlib.lines.Line2D at 0x1cfcf2d0e50>,
#   <matplotlib.lines.Line2D at 0x1cfcd1a6a00>,
#   <matplotlib.lines.Line2D at 0x1cfcf2b8460>,
#   <matplotlib.lines.Line2D at 0x1cfcf2b8940>,
#   <matplotlib.lines.Line2D at 0x1cfcf2b8e20>,
#   <matplotlib.lines.Line2D at 0x1cfcd525340>,
#   <matplotlib.lines.Line2D at 0x1cfcd525820>,
#   <matplotlib.lines.Line2D at 0x1cfcd525d00>,
#   <matplotlib.lines.Line2D at 0x1cfcd522220>,
#   <matplotlib.lines.Line2D at 0x1cfcd522700>,
#   <matplotlib.lines.Line2D at 0x1cfcd522be0>,
#   <matplotlib.lines.Line2D at 0x1cfcd534100>,
#   <matplotlib.lines.Line2D at 0x1cfcd5345e0>,
#   <matplotlib.lines.Line2D at 0x1cfcd534ac0>,
#   <matplotlib.lines.Line2D at 0x1cfcd534fa0>,
#   <matplotlib.lines.Line2D at 0x1cfd394c4c0>,
#   <matplotlib.lines.Line2D at 0x1cfd394c9a0>,
#   <matplotlib.lines.Line2D at 0x1cfd394ce80>,
#   <matplotlib.lines.Line2D at 0x1cfd39773a0>,
#   <matplotlib.lines.Line2D at 0x1cfd3977880>,
#   <matplotlib.lines.Line2D at 0x1cfd3977d60>,
#   <matplotlib.lines.Line2D at 0x1cfd3951280>,
#   <matplotlib.lines.Line2D at 0x1cfd3951760>,
#   <matplotlib.lines.Line2D at 0x1cfd3951c40>,
#   <matplotlib.lines.Line2D at 0x1cfcd719160>,
#   <matplotlib.lines.Line2D at 0x1cfcd719640>,
#   <matplotlib.lines.Line2D at 0x1cfcd719b20>,
#   <matplotlib.lines.Line2D at 0x1cfcd719fa0>,
#   <matplotlib.lines.Line2D at 0x1cfcd715520>,
#   <matplotlib.lines.Line2D at 0x1cfcd715a00>,
#   <matplotlib.lines.Line2D at 0x1cfcd715ee0>,
#   <matplotlib.lines.Line2D at 0x1cfcd724400>,
#   <matplotlib.lines.Line2D at 0x1cfcd7248e0>,
#   <matplotlib.lines.Line2D at 0x1cfcd724dc0>,
#   <matplotlib.lines.Line2D at 0x1cfcd7352e0>,
#   <matplotlib.lines.Line2D at 0x1cfcd7357c0>,
#   <matplotlib.lines.Line2D at 0x1cfcd735ca0>,
#   <matplotlib.lines.Line2D at 0x1cfd65f01c0>,
#   <matplotlib.lines.Line2D at 0x1cfd65f06a0>,
#   <matplotlib.lines.Line2D at 0x1cfd65f0b80>,
#   <matplotlib.lines.Line2D at 0x1cfd65f0fd0>,
#   <matplotlib.lines.Line2D at 0x1cfd65e2580>,
#   <matplotlib.lines.Line2D at 0x1cfd65e2a60>,
#   <matplotlib.lines.Line2D at 0x1cfd65e2f40>,
#   <matplotlib.lines.Line2D at 0x1cfd65c9460>,
#   <matplotlib.lines.Line2D at 0x1cfd65c9940>,
#   <matplotlib.lines.Line2D at 0x1cfd65c9e20>,
#   <matplotlib.lines.Line2D at 0x1cfd17a5340>,
#   <matplotlib.lines.Line2D at 0x1cfd17a5820>,
#   <matplotlib.lines.Line2D at 0x1cfd17a5d30>,
#   <matplotlib.lines.Line2D at 0x1cfd17b4250>,
#   <matplotlib.lines.Line2D at 0x1cfd17b4730>,
#   <matplotlib.lines.Line2D at 0x1cfd17b4c10>,
#   <matplotlib.lines.Line2D at 0x1cfd17a0130>,
#   <matplotlib.lines.Line2D at 0x1cfd17a0610>,
#   <matplotlib.lines.Line2D at 0x1cfd17a0af0>,
#   <matplotlib.lines.Line2D at 0x1cfd17a0fd0>,
#   <matplotlib.lines.Line2D at 0x1cfd17a24f0>,
#   <matplotlib.lines.Line2D at 0x1cfd17a29d0>,
#   <matplotlib.lines.Line2D at 0x1cfd17a2eb0>,
#   <matplotlib.lines.Line2D at 0x1cfccd023d0>,
#   <matplotlib.lines.Line2D at 0x1cfccd028b0>,
#   <matplotlib.lines.Line2D at 0x1cfccd02d90>,
#   <matplotlib.lines.Line2D at 0x1cfccd05100>,
#   <matplotlib.lines.Line2D at 0x1cfccd05520>,
#   <matplotlib.lines.Line2D at 0x1cfccd05f10>,
#   <matplotlib.lines.Line2D at 0x1cfcccd3190>,
#   <matplotlib.lines.Line2D at 0x1cfcccd3670>,
#   <matplotlib.lines.Line2D at 0x1cfcccd3b50>,
#   <matplotlib.lines.Line2D at 0x1cfcccd3fd0>,
#   <matplotlib.lines.Line2D at 0x1cfcd23d040>,
#   <matplotlib.lines.Line2D at 0x1cfcd23daf0>,
#   <matplotlib.lines.Line2D at 0x1cfcd23db80>,
#   <matplotlib.lines.Line2D at 0x1cfcd21d430>,
#   <matplotlib.lines.Line2D at 0x1cfcd21d910>,
#   <matplotlib.lines.Line2D at 0x1cfcd21ddf0>,
#   <matplotlib.lines.Line2D at 0x1cfcd223310>,
#   <matplotlib.lines.Line2D at 0x1cfcd2237f0>,
#   <matplotlib.lines.Line2D at 0x1cfcd223cd0>,
#   <matplotlib.lines.Line2D at 0x1cfcd2241f0>,
#   <matplotlib.lines.Line2D at 0x1cfcd2246d0>,
#   <matplotlib.lines.Line2D at 0x1cfcd224bb0>,
#   <matplotlib.lines.Line2D at 0x1cfcd224fd0>,
#   <matplotlib.lines.Line2D at 0x1cfd3f0d5b0>,
#   <matplotlib.lines.Line2D at 0x1cfd3f0da90>,
#   <matplotlib.lines.Line2D at 0x1cfd3f0df70>,
#   <matplotlib.lines.Line2D at 0x1cfd3f0c490>,
#   <matplotlib.lines.Line2D at 0x1cfd3f0c970>,
#   <matplotlib.lines.Line2D at 0x1cfd3f0ce50>,
#   <matplotlib.lines.Line2D at 0x1cfd3ed0370>,
#   <matplotlib.lines.Line2D at 0x1cfd3ed0850>,
#   <matplotlib.lines.Line2D at 0x1cfd3ed0d30>,
#   <matplotlib.lines.Line2D at 0x1cfcdecd250>,
#   <matplotlib.lines.Line2D at 0x1cfcdecd730>,
#   <matplotlib.lines.Line2D at 0x1cfcdecdc10>,
#   <matplotlib.lines.Line2D at 0x1cfcdea3130>,
#   <matplotlib.lines.Line2D at 0x1cfcdea3610>,
#   <matplotlib.lines.Line2D at 0x1cfcdea3af0>,
#   <matplotlib.lines.Line2D at 0x1cfcdea3fd0>,
#   <matplotlib.lines.Line2D at 0x1cfcded54f0>,
#   <matplotlib.lines.Line2D at 0x1cfcded59d0>,
#   <matplotlib.lines.Line2D at 0x1cfcded5eb0>,
#   <matplotlib.lines.Line2D at 0x1cfcdecb3d0>,
#   <matplotlib.lines.Line2D at 0x1cfcdecb8b0>,
#   <matplotlib.lines.Line2D at 0x1cfcdecbd90>,
#   <matplotlib.lines.Line2D at 0x1cfcca922b0>,
#   <matplotlib.lines.Line2D at 0x1cfcca92790>,
#   <matplotlib.lines.Line2D at 0x1cfcca92c70>,
#   <matplotlib.lines.Line2D at 0x1cfccaa8190>,
#   <matplotlib.lines.Line2D at 0x1cfccaa8670>,
#   <matplotlib.lines.Line2D at 0x1cfccaa8b50>,
#   <matplotlib.lines.Line2D at 0x1cfccaa8fd0>,
#   <matplotlib.lines.Line2D at 0x1cfccac02e0>,
#   <matplotlib.lines.Line2D at 0x1cfccac0790>,
#   <matplotlib.lines.Line2D at 0x1cfccac0f40>,
#   <matplotlib.lines.Line2D at 0x1cfccabc430>,
#   <matplotlib.lines.Line2D at 0x1cfccabc910>,
#   <matplotlib.lines.Line2D at 0x1cfccabcdf0>,
#   <matplotlib.lines.Line2D at 0x1cfd6db3310>,
#   <matplotlib.lines.Line2D at 0x1cfd6db37f0>,
#   <matplotlib.lines.Line2D at 0x1cfd6db3cd0>,
#   <matplotlib.lines.Line2D at 0x1cfd6da01f0>,
#   <matplotlib.lines.Line2D at 0x1cfd6da06d0>,
#   <matplotlib.lines.Line2D at 0x1cfd6da0bb0>,
#   <matplotlib.lines.Line2D at 0x1cfd6da0fd0>,
#   <matplotlib.lines.Line2D at 0x1cfd6d925b0>,
#   <matplotlib.lines.Line2D at 0x1cfd6d92a90>,
#   <matplotlib.lines.Line2D at 0x1cfd6d92f70>,
#   <matplotlib.lines.Line2D at 0x1cfcc873490>,
#   <matplotlib.lines.Line2D at 0x1cfcc873970>,
#   <matplotlib.lines.Line2D at 0x1cfcc873e50>,
#   <matplotlib.lines.Line2D at 0x1cfcc86f370>,
#   <matplotlib.lines.Line2D at 0x1cfcc86f850>,
#   <matplotlib.lines.Line2D at 0x1cfcc86fd30>,
#   <matplotlib.lines.Line2D at 0x1cfcc87a250>,
#   <matplotlib.lines.Line2D at 0x1cfcc87a730>,
#   <matplotlib.lines.Line2D at 0x1cfcc87ac10>,
#   <matplotlib.lines.Line2D at 0x1cfcc867130>,
#   <matplotlib.lines.Line2D at 0x1cfcc867610>,
#   <matplotlib.lines.Line2D at 0x1cfcc867af0>,
#   <matplotlib.lines.Line2D at 0x1cfcc867fd0>,
#   <matplotlib.lines.Line2D at 0x1cfccdcf4f0>,
#   <matplotlib.lines.Line2D at 0x1cfccdcf9d0>,
#   <matplotlib.lines.Line2D at 0x1cfccdcfeb0>,
#   <matplotlib.lines.Line2D at 0x1cfccdab3d0>,
#   <matplotlib.lines.Line2D at 0x1cfccdab8b0>,
#   <matplotlib.lines.Line2D at 0x1cfccdabd90>,
#   <matplotlib.lines.Line2D at 0x1cfccdaa2b0>,
#   <matplotlib.lines.Line2D at 0x1cfccdaa790>,
#   <matplotlib.lines.Line2D at 0x1cfccdaac70>,
#   <matplotlib.lines.Line2D at 0x1cfccdca190>,
#   <matplotlib.lines.Line2D at 0x1cfccdca670>,
#   <matplotlib.lines.Line2D at 0x1cfccdcab50>,
#   <matplotlib.lines.Line2D at 0x1cfccdcafd0>,
#   <matplotlib.lines.Line2D at 0x1cfcc9ba550>,
#   <matplotlib.lines.Line2D at 0x1cfcc9baa30>,
#   <matplotlib.lines.Line2D at 0x1cfcc9baf10>,
#   <matplotlib.lines.Line2D at 0x1cfcc9cd430>,
#   <matplotlib.lines.Line2D at 0x1cfcc9cd910>,
#   <matplotlib.lines.Line2D at 0x1cfcc9cddf0>,
#   <matplotlib.lines.Line2D at 0x1cfcc9c3310>,
#   <matplotlib.lines.Line2D at 0x1cfcc9c37f0>,
#   <matplotlib.lines.Line2D at 0x1cfcc9c3cd0>,
#   <matplotlib.lines.Line2D at 0x1cfcc9971f0>,
#   <matplotlib.lines.Line2D at 0x1cfcc9976d0>,
#   <matplotlib.lines.Line2D at 0x1cfcc997bb0>,
#   <matplotlib.lines.Line2D at 0x1cfcc997fd0>,
#   <matplotlib.lines.Line2D at 0x1cfcc4e35b0>,
#   <matplotlib.lines.Line2D at 0x1cfcc4e3a90>,
#   <matplotlib.lines.Line2D at 0x1cfcc4e3f70>,
#   <matplotlib.lines.Line2D at 0x1cfcc4d9490>,
#   <matplotlib.lines.Line2D at 0x1cfcc4d9970>,
#   <matplotlib.lines.Line2D at 0x1cfcc4d9e50>,
#   <matplotlib.lines.Line2D at 0x1cfcc4ee370>,
#   <matplotlib.lines.Line2D at 0x1cfcc4ee850>,
#   <matplotlib.lines.Line2D at 0x1cfcc4eed30>,
#   <matplotlib.lines.Line2D at 0x1cfcc4ea250>,
#   <matplotlib.lines.Line2D at 0x1cfcc4ea730>,
#   <matplotlib.lines.Line2D at 0x1cfcc4eac10>,
#   <matplotlib.lines.Line2D at 0x1cfcc67f130>,
#   <matplotlib.lines.Line2D at 0x1cfcc67f610>,
#   <matplotlib.lines.Line2D at 0x1cfcc67faf0>,
#   <matplotlib.lines.Line2D at 0x1cfcc67ffd0>,
#   <matplotlib.lines.Line2D at 0x1cfcc6724f0>,
#   <matplotlib.lines.Line2D at 0x1cfcc6729d0>,
#   <matplotlib.lines.Line2D at 0x1cfcc672eb0>,
#   <matplotlib.lines.Line2D at 0x1cfcc6853d0>,
#   <matplotlib.lines.Line2D at 0x1cfcc6858b0>,
#   <matplotlib.lines.Line2D at 0x1cfcc685d90>,
#   <matplotlib.lines.Line2D at 0x1cfcc6662b0>,
#   <matplotlib.lines.Line2D at 0x1cfcc666790>,
#   <matplotlib.lines.Line2D at 0x1cfcc666c70>,
#   <matplotlib.lines.Line2D at 0x1cfcf2e1190>,
#   <matplotlib.lines.Line2D at 0x1cfcf2e1670>,
#   <matplotlib.lines.Line2D at 0x1cfcf2e1b50>,
#   <matplotlib.lines.Line2D at 0x1cfcf2e1fd0>,
#   <matplotlib.lines.Line2D at 0x1cfcf2ec550>,
#   <matplotlib.lines.Line2D at 0x1cfcf2eca30>,
#   <matplotlib.lines.Line2D at 0x1cfcf2ecf10>,
#   <matplotlib.lines.Line2D at 0x1cfcf2fd430>,
#   <matplotlib.lines.Line2D at 0x1cfcf2fd910>,
#   <matplotlib.lines.Line2D at 0x1cfcf2fddf0>,
#   <matplotlib.lines.Line2D at 0x1cfcf31d310>,
#   <matplotlib.lines.Line2D at 0x1cfcf31d7f0>,
#   <matplotlib.lines.Line2D at 0x1cfcf31dcd0>,
#   <matplotlib.lines.Line2D at 0x1cfcc9761f0>,
#   <matplotlib.lines.Line2D at 0x1cfcc9766d0>,
#   <matplotlib.lines.Line2D at 0x1cfcc976bb0>],
#  [<matplotlib.patches.Rectangle at 0x1cfcdebb430>,
#   <matplotlib.patches.Rectangle at 0x1cfccba57c0>,
#   <matplotlib.patches.Rectangle at 0x1cfd308ebb0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2c13d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2a74c0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2a7f10>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2a7b80>,
#   <matplotlib.patches.Rectangle at 0x1cfd31e6100>,
#   <matplotlib.patches.Rectangle at 0x1cfd31e64f0>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f2b910>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f2b8e0>,
#   <matplotlib.patches.Rectangle at 0x1cfccd63eb0>,
#   <matplotlib.patches.Rectangle at 0x1cfccd63520>,
#   <matplotlib.patches.Rectangle at 0x1cfccd63460>,
#   <matplotlib.patches.Rectangle at 0x1cfc146a970>,
#   <matplotlib.patches.Rectangle at 0x1cfd9fc2610>,
#   <matplotlib.patches.Rectangle at 0x1cfd9fc2a30>,
#   <matplotlib.patches.Rectangle at 0x1cfd9fc2f10>,
#   <matplotlib.patches.Rectangle at 0x1cfcd290430>,
#   <matplotlib.patches.Rectangle at 0x1cfcd290910>,
#   <matplotlib.patches.Rectangle at 0x1cfcd290df0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd299310>,
#   <matplotlib.patches.Rectangle at 0x1cfcd2997f0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd299cd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc5431f0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc5436d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc543bb0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc543fd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc5595b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc559a90>,
#   <matplotlib.patches.Rectangle at 0x1cfcc559f70>,
#   <matplotlib.patches.Rectangle at 0x1cfcc54c490>,
#   <matplotlib.patches.Rectangle at 0x1cfcc54c970>,
#   <matplotlib.patches.Rectangle at 0x1cfcc54ce50>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2cc370>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2cc850>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2ccd30>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2a6130>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2a6730>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2a6c10>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2a6fd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2d0610>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2d0af0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2d0fd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd1a6220>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2b85e0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2b8ac0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2b8fa0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd5254c0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd5259a0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd525e80>,
#   <matplotlib.patches.Rectangle at 0x1cfcd5223a0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd522880>,
#   <matplotlib.patches.Rectangle at 0x1cfcd522d60>,
#   <matplotlib.patches.Rectangle at 0x1cfcd534280>,
#   <matplotlib.patches.Rectangle at 0x1cfcd534760>,
#   <matplotlib.patches.Rectangle at 0x1cfcd534c40>,
#   <matplotlib.patches.Rectangle at 0x1cfd394c040>,
#   <matplotlib.patches.Rectangle at 0x1cfd394c640>,
#   <matplotlib.patches.Rectangle at 0x1cfd394cb20>,
#   <matplotlib.patches.Rectangle at 0x1cfd394cf40>,
#   <matplotlib.patches.Rectangle at 0x1cfd3977520>,
#   <matplotlib.patches.Rectangle at 0x1cfd3977a00>,
#   <matplotlib.patches.Rectangle at 0x1cfd3977ee0>,
#   <matplotlib.patches.Rectangle at 0x1cfd3951400>,
#   <matplotlib.patches.Rectangle at 0x1cfd39518e0>,
#   <matplotlib.patches.Rectangle at 0x1cfd3951dc0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd7192e0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd7197c0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd719ca0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd7151c0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd7156a0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd715b80>,
#   <matplotlib.patches.Rectangle at 0x1cfcd715f40>,
#   <matplotlib.patches.Rectangle at 0x1cfcd724580>,
#   <matplotlib.patches.Rectangle at 0x1cfcd724a60>,
#   <matplotlib.patches.Rectangle at 0x1cfcd724f40>,
#   <matplotlib.patches.Rectangle at 0x1cfcd735460>,
#   <matplotlib.patches.Rectangle at 0x1cfcd735940>,
#   <matplotlib.patches.Rectangle at 0x1cfcd735e20>,
#   <matplotlib.patches.Rectangle at 0x1cfd65f0340>,
#   <matplotlib.patches.Rectangle at 0x1cfd65f0820>,
#   <matplotlib.patches.Rectangle at 0x1cfd65f0d00>,
#   <matplotlib.patches.Rectangle at 0x1cfd65e2100>,
#   <matplotlib.patches.Rectangle at 0x1cfd65e2700>,
#   <matplotlib.patches.Rectangle at 0x1cfd65e2be0>,
#   <matplotlib.patches.Rectangle at 0x1cfd65e2fa0>,
#   <matplotlib.patches.Rectangle at 0x1cfd65c95e0>,
#   <matplotlib.patches.Rectangle at 0x1cfd65c9ac0>,
#   <matplotlib.patches.Rectangle at 0x1cfd65c9fa0>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a54c0>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a59a0>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a5eb0>,
#   <matplotlib.patches.Rectangle at 0x1cfd17b43d0>,
#   <matplotlib.patches.Rectangle at 0x1cfd17b48b0>,
#   <matplotlib.patches.Rectangle at 0x1cfd17b4d90>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a02b0>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a0790>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a0c70>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a2070>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a2670>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a2b50>,
#   <matplotlib.patches.Rectangle at 0x1cfd17a2fa0>,
#   <matplotlib.patches.Rectangle at 0x1cfccd02550>,
#   <matplotlib.patches.Rectangle at 0x1cfccd02a30>,
#   <matplotlib.patches.Rectangle at 0x1cfccd02f10>,
#   <matplotlib.patches.Rectangle at 0x1cfccd05280>,
#   <matplotlib.patches.Rectangle at 0x1cfccd05970>,
#   <matplotlib.patches.Rectangle at 0x1cfccd05d60>,
#   <matplotlib.patches.Rectangle at 0x1cfcccd3310>,
#   <matplotlib.patches.Rectangle at 0x1cfcccd37f0>,
#   <matplotlib.patches.Rectangle at 0x1cfcccd3cd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd23d8b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd23d790>,
#   <matplotlib.patches.Rectangle at 0x1cfcd23d400>,
#   <matplotlib.patches.Rectangle at 0x1cfcd23db50>,
#   <matplotlib.patches.Rectangle at 0x1cfcd21d5b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcd21da90>,
#   <matplotlib.patches.Rectangle at 0x1cfcd21df70>,
#   <matplotlib.patches.Rectangle at 0x1cfcd223490>,
#   <matplotlib.patches.Rectangle at 0x1cfcd223970>,
#   <matplotlib.patches.Rectangle at 0x1cfcd223e50>,
#   <matplotlib.patches.Rectangle at 0x1cfcd224370>,
#   <matplotlib.patches.Rectangle at 0x1cfcd224850>,
#   <matplotlib.patches.Rectangle at 0x1cfcd224d30>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f0d130>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f0d730>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f0dc10>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f0dfd0>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f0c610>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f0caf0>,
#   <matplotlib.patches.Rectangle at 0x1cfd3f0cfd0>,
#   <matplotlib.patches.Rectangle at 0x1cfd3ed04f0>,
#   <matplotlib.patches.Rectangle at 0x1cfd3ed09d0>,
#   <matplotlib.patches.Rectangle at 0x1cfd3ed0eb0>,
#   <matplotlib.patches.Rectangle at 0x1cfcdecd3d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcdecd8b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcdecdd90>,
#   <matplotlib.patches.Rectangle at 0x1cfcdea32b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcdea3790>,
#   <matplotlib.patches.Rectangle at 0x1cfcdea3c70>,
#   <matplotlib.patches.Rectangle at 0x1cfcded5070>,
#   <matplotlib.patches.Rectangle at 0x1cfcded5670>,
#   <matplotlib.patches.Rectangle at 0x1cfcded5b50>,
#   <matplotlib.patches.Rectangle at 0x1cfcded5fa0>,
#   <matplotlib.patches.Rectangle at 0x1cfcdecb550>,
#   <matplotlib.patches.Rectangle at 0x1cfcdecba30>,
#   <matplotlib.patches.Rectangle at 0x1cfcdecbf10>,
#   <matplotlib.patches.Rectangle at 0x1cfcca92430>,
#   <matplotlib.patches.Rectangle at 0x1cfcca92910>,
#   <matplotlib.patches.Rectangle at 0x1cfcca92df0>,
#   <matplotlib.patches.Rectangle at 0x1cfccaa8310>,
#   <matplotlib.patches.Rectangle at 0x1cfccaa87f0>,
#   <matplotlib.patches.Rectangle at 0x1cfccaa8cd0>,
#   <matplotlib.patches.Rectangle at 0x1cfccac0160>,
#   <matplotlib.patches.Rectangle at 0x1cfccac05b0>,
#   <matplotlib.patches.Rectangle at 0x1cfccac0a30>,
#   <matplotlib.patches.Rectangle at 0x1cfccac0f10>,
#   <matplotlib.patches.Rectangle at 0x1cfccabc5b0>,
#   <matplotlib.patches.Rectangle at 0x1cfccabca90>,
#   <matplotlib.patches.Rectangle at 0x1cfccabcf70>,
#   <matplotlib.patches.Rectangle at 0x1cfd6db3490>,
#   <matplotlib.patches.Rectangle at 0x1cfd6db3970>,
#   <matplotlib.patches.Rectangle at 0x1cfd6db3e50>,
#   <matplotlib.patches.Rectangle at 0x1cfd6da0370>,
#   <matplotlib.patches.Rectangle at 0x1cfd6da0850>,
#   <matplotlib.patches.Rectangle at 0x1cfd6da0d30>,
#   <matplotlib.patches.Rectangle at 0x1cfd6d92130>,
#   <matplotlib.patches.Rectangle at 0x1cfd6d92730>,
#   <matplotlib.patches.Rectangle at 0x1cfd6d92c10>,
#   <matplotlib.patches.Rectangle at 0x1cfd6d92fd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc873610>,
#   <matplotlib.patches.Rectangle at 0x1cfcc873af0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc873fd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc86f4f0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc86f9d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc86feb0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc87a3d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc87a8b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc87ad90>,
#   <matplotlib.patches.Rectangle at 0x1cfcc8672b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc867790>,
#   <matplotlib.patches.Rectangle at 0x1cfcc867c70>,
#   <matplotlib.patches.Rectangle at 0x1cfccdcf190>,
#   <matplotlib.patches.Rectangle at 0x1cfccdcf670>,
#   <matplotlib.patches.Rectangle at 0x1cfccdcfb50>,
#   <matplotlib.patches.Rectangle at 0x1cfccdcffa0>,
#   <matplotlib.patches.Rectangle at 0x1cfccdab550>,
#   <matplotlib.patches.Rectangle at 0x1cfccdaba30>,
#   <matplotlib.patches.Rectangle at 0x1cfccdabf10>,
#   <matplotlib.patches.Rectangle at 0x1cfccdaa430>,
#   <matplotlib.patches.Rectangle at 0x1cfccdaa910>,
#   <matplotlib.patches.Rectangle at 0x1cfccdaadf0>,
#   <matplotlib.patches.Rectangle at 0x1cfccdca310>,
#   <matplotlib.patches.Rectangle at 0x1cfccdca7f0>,
#   <matplotlib.patches.Rectangle at 0x1cfccdcacd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9ba1f0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9ba6d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9babb0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9bafd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9cd5b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9cda90>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9cdf70>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9c3490>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9c3970>,
#   <matplotlib.patches.Rectangle at 0x1cfcc9c3e50>,
#   <matplotlib.patches.Rectangle at 0x1cfcc997370>,
#   <matplotlib.patches.Rectangle at 0x1cfcc997850>,
#   <matplotlib.patches.Rectangle at 0x1cfcc997d30>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4e3130>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4e3730>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4e3c10>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4e3fd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4d9610>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4d9af0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4d9fd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4ee4f0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4ee9d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4eeeb0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4ea3d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4ea8b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc4ead90>,
#   <matplotlib.patches.Rectangle at 0x1cfcc67f2b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc67f790>,
#   <matplotlib.patches.Rectangle at 0x1cfcc67fc70>,
#   <matplotlib.patches.Rectangle at 0x1cfcc672070>,
#   <matplotlib.patches.Rectangle at 0x1cfcc672670>,
#   <matplotlib.patches.Rectangle at 0x1cfcc672b50>,
#   <matplotlib.patches.Rectangle at 0x1cfcc672fa0>,
#   <matplotlib.patches.Rectangle at 0x1cfcc685550>,
#   <matplotlib.patches.Rectangle at 0x1cfcc685a30>,
#   <matplotlib.patches.Rectangle at 0x1cfcc685f10>,
#   <matplotlib.patches.Rectangle at 0x1cfcc666430>,
#   <matplotlib.patches.Rectangle at 0x1cfcc666910>,
#   <matplotlib.patches.Rectangle at 0x1cfcc666df0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2e1310>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2e17f0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2e1cd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2ec0d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2ec6d0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2ecbb0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2ecfd0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2fd5b0>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2fda90>,
#   <matplotlib.patches.Rectangle at 0x1cfcf2fdf70>,
#   <matplotlib.patches.Rectangle at 0x1cfcf31d490>,
#   <matplotlib.patches.Rectangle at 0x1cfcf31d970>,
#   <matplotlib.patches.Rectangle at 0x1cfcf31de50>,
#   <matplotlib.patches.Rectangle at 0x1cfcc976370>,
#   <matplotlib.patches.Rectangle at 0x1cfcc976850>,
#   <matplotlib.patches.Rectangle at 0x1cfcc976d30>])

# %%
date_format = mdates.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(date_format)
fig.autofmt_xdate()

# %%
ax.set_title('Candlestick Chart')
ax.set_xlabel('Date')
ax.set_ylabel('Price ($)')
# Out:
# Text(103.72222222222221, 0.5, 'Price ($)')

# %%
fig.savefig('my_plot.png')
plt.show()

# %%
Image(filename='my_plot.png')

# %%
df["Date"]
# Out:
# Date
# 2020-01-02 00:00:00-05:00    18263.208333
# 2020-01-03 00:00:00-05:00    18264.208333
# 2020-01-06 00:00:00-05:00    18267.208333
# 2020-01-07 00:00:00-05:00    18268.208333
# 2020-01-08 00:00:00-05:00    18269.208333
#                                  ...
# 2023-03-01 00:00:00-05:00    19417.208333
# 2023-03-02 00:00:00-05:00    19418.208333
# 2023-03-03 00:00:00-05:00    19419.208333
# 2023-03-06 00:00:00-05:00    19422.208333
# 2023-03-07 00:00:00-05:00    19423.208333
# Name: Date, Length: 800, dtype: float64

# %%
def isSupport(df,i):
  support = df['Low'][i] < df['Low'][i-1]  and df['Low'][i] < df['Low'][i+1] and df['Low'][i+1] < df['Low'][i+2] and df['Low'][i-1] < df['Low'][i-2]
  return support

def isResistance(df,i):
  resistance = df['High'][i] > df['High'][i-1]  and df['High'][i] > df['High'][i+1] and df['High'][i+1] > df['High'][i+2] and df['High'][i-1] > df['High'][i-2]
  return resistance

# %%
levels = []
levelr = []

for i in range(2,df.shape[0]-2):
  if isSupport(df,i):
    levels.append((i,df['Low'][i]))
    
  elif isResistance(df,i):
    levelr.append((i,df['High'][i]))

# %%
def plot_all():
  fig, ax = plt.subplots()
  mpf.candlestick_ohlc(ax,df[['Date','Open', 'High', 'Low', 'Close']].values,width=0.8,colorup='green', colordown='red', alpha=0.8)
  date_format = mdates.DateFormatter('%d %b %Y')
  ax.xaxis.set_major_formatter(date_format)
  fig.autofmt_xdate()
  ax.set_title('Support/Resistance Candlestick Chart',color='#800080')
  ax.set_xlabel('Date',color='#800080')
  ax.xaxis.label.set_facecolor('lightgrey')
  ax.set_ylabel('Price ($)',color='#800080')
  fig.tight_layout()
    
  support_label = 'Support'
  resistance_label = 'Resistance'
  
  support_lines = []
  for level in levels:
    line = plt.hlines(level[1],xmin=df['Date'][level[0]],xmax=max(df['Date']),colors='blue',label=support_label)
    support_lines.append(line)
  
  resistance_lines = []
  for level in levelr:
    line = plt.hlines(level[1],xmin=df['Date'][level[0]],xmax=max(df['Date']),colors='#DEC20B',label=resistance_label)
    resistance_lines.append(line)
    
  legend_lines = [Line2D([0], [0], color='blue', lw=2, label=support_label), Line2D([0], [0], color='#DEC20B', lw=2, label=resistance_label)]
  ax.legend(handles=legend_lines,facecolor='lightgrey', framealpha=1.0)
  fig.savefig('noisy_sup_res.png')
  fig.show()

# %%
plot_all()

# %%
Image(filename='noisy_sup_res.png')

# %%
s =  np.mean(df['High'] - df['Low'])

# %%
def isFarFromLevel(l):
   return np.sum([abs(l-x) < s  for x in level]) == 0

# %%
level = []
for i in range(2,df.shape[0]-2):
  if isSupport(df,i):
    l = df['Low'][i]
    if isFarFromLevel(l):
      level.append((i,l))
  elif isResistance(df,i):
    l = df['High'][i]
    if isFarFromLevel(l):
      level.append((i,l))

# %%
def plot_all2():
  fig, ax = plt.subplots()
  mpf.candlestick_ohlc(ax,df[['Date','Open', 'High', 'Low', 'Close']].values,width=0.8,colorup='green', colordown='red', alpha=0.8)
  date_format = mdates.DateFormatter('%d %b %Y')
  ax.xaxis.set_major_formatter(date_format)
  fig.autofmt_xdate()
  fig.tight_layout()
  for levell in levels:
    plt.hlines(levell[1],xmin=df['Date'][levell[0]],xmax=max(df['Date']),colors='blue')
    fig.savefig('sup_res.png')
#     fig.show()

# %%
plot_all2()

# %%
plt.hlines?

# %%
Image(filename='sup_res.png')

# %%
# ax.legend?

ax.set_xlabel?
